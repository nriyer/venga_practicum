# %% [markdown]
# ## Exploring the 3 sample data sets

# %% [markdown]
# ### First set (sheet one)

# %%
# !csvcut sheet_one.csv -n
# Out:
#   1: check_number
#   2: code
#   3: created_on_utc
#   4: loyalty_reservation_id
#   5: is_walkin
#   6: loyalty_user_id
#   7: made_on
#   8: modified_on_utc
#   9: ordinal
#  10: parent_venue_id
#  11: party_size
#  12: reservation_date
#  13: server_modified_on_utc
#  14: server_name
#  15: state
#  16: table_name
#  17: venue_id

# %%
# !csvstat sheet_one.csv
# Out:
#   1. check_number
# 	<type 'int'>
# 	Nulls: False
# 	Min: 0
# 	Max: 6764
# 	Sum: 36815
# 	Mean: 368.15
# 	Median: 111.5
# 	Standard Deviation: 710.570775856
# 	Unique values: 72
# 	5 most frequent values:
# 		0:	25
# 		727:	3
# 		87:	2
# 		564:	2
# 		604:	1
#   2. code
# 	<type 'unicode'>
# 	Nulls: True
# 	Values: Web Reservation, Excluded From Pacing, Birthday, Hotel Referral, SEE NOTE!!!!
#   3. created_on_utc
# 	<type 'int'>
# 	Nulls: False
# 	Min: 1451976147
# 	Max: 1452062443
# 	Sum: 145199182813
# 	Mean: 1451991828.13
# 	Median: 1451976862.5
# 	Standard Deviation: 26863.7644915
# 	Unique values: 74
# 	5 most frequent values:
# 		1451992937:	3
# 		1451992935:	3
# 		1451976161:	3
# 		1451976155:	3
# 		1452024309:	2
#   4. loyalty_reservation_id
# 	<type 'int'>
# 	Nulls: False
# 	Min: 73454976
# 	Max: 73478904
# 	Sum: 7346037289
# 	Mean: 73460372.89
# 	Median: 73455899.5
# 	Standard Deviation: 7692.02833444
# 	Unique values: 96
# 	5 most frequent values:
# 		73463194:	3
# ...

# %%
sheet1 <- read.csv('sheet_one.csv')

# %%
str(sheet1)

# %%
sum(is.na(sheet1))

# %% [markdown]
# no missing values

# %%
# !csvcut POS.csv -n
# Out:
#   1: check_number
#   2: cover_count
#   3: created_on_utc
#   4: discount
#   5: gratuity
#   6: loyalty_visit_id
#   7: loyalty_reservation_id
#   8: loyalty_user_id
#   9: modified_on_utc
#  10: open_date
#  11: ordinal
#  12: parent_venue_id
#  13: server_id
#  14: server_modified_on_utc
#  15: server_name
#  16: spend
#  17: table_name
#  18: terminal_id
#  19: venue_id
#  20: visit_date

# %%
# !csvstat POS.csv
# Out:
#   1. check_number
# 	<type 'int'>
# 	Nulls: False
# 	Min: 1
# 	Max: 127
# 	Sum: 5672
# 	Mean: 56.72
# 	Median: 53.5
# 	Standard Deviation: 35.0223014664
# 	Unique values: 100
#   2. cover_count
# 	<type 'int'>
# 	Nulls: False
# 	Values: 1, 2, 3, 4
#   3. created_on_utc
# 	<type 'int'>
# 	Nulls: False
# 	Min: 1451993268
# 	Max: 1451993416
# 	Sum: 145199333375
# 	Mean: 1451993333.75
# 	Median: 1451993325.5
# 	Standard Deviation: 43.6037555722
# 	Unique values: 78
# 	5 most frequent values:
# 		1451993280:	4
# 		1451993290:	3
# 		1451993392:	2
# 		1451993291:	2
# 		1451993295:	2
#   4. discount
# 	<type 'int'>
# 	Nulls: False
# 	Min: 0
# 	Max: 52
# 	Sum: 304
# 	Mean: 3.04
# 	Median: 0.0
# 	Standard Deviation: 8.66824088267
# 	Unique values: 14
# 	5 most frequent values:
# 		0:	85
# 		11:	2
# 		27:	2
# 		25:	1
# 		13:	1
#   5. gratuity
# 	<type 'float'>
# 	Nulls: False
# 	Min: 0.0
# 	Max: 22.0
# 	Sum: 503.18
# 	Mean: 5.0318
# 	Median: 3.0
# 	Standard Deviation: 5.81164768031
# ...

# %%
POS <- read.csv('POS.csv')

# %%
sum(is.na(POS))
# Out:
# [1] 0

# %%
# !csvcut POS_items.csv -n
# Out:
#   1: amount
#   2: amount_per_unit
#   3: created_on_utc
#   4: discount
#   5: loyalty_visit_id
#   6: item_category_id
#   7: item_category_name
#   8: item_id
#   9: item_name
#  10: item_subcategory_id
#  11: item_subcategory_name
#  12: loyalty_category_name
#  13: loyalty_reservation_id
#  14: loyalty_visit_item_id
#  15: modified_on_utc
#  16: ordinal
#  17: parent_venue_id
#  18: quantity
#  19: quantity_amount_nz
#  20: server_modified_on_utc
#  21: venue_id
#  22: visit_cover_count
#  23: visit_date
#  24: visit_open_date
#  25: visit_spend

# %%
# !csvstat POS_items.csv
# Out:
#   1. amount
# 	<type 'float'>
# 	Nulls: False
# 	Min: -52.0
# 	Max: 15.5
# 	Sum: 220.5
# 	Mean: 2.205
# 	Median: 0.0
# 	Standard Deviation: 7.53956066359
# 	Unique values: 21
# 	5 most frequent values:
# 		0.0:	53
# 		6.5:	9
# 		9.0:	7
# 		2.95:	5
# 		1.5:	3
#   2. amount_per_unit
# 	<type 'float'>
# 	Nulls: False
# 	Min: -52.0
# 	Max: 15.5
# 	Sum: 220.5
# 	Mean: 2.205
# 	Median: 0.0
# 	Standard Deviation: 7.53956066359
# 	Unique values: 21
# 	5 most frequent values:
# 		0.0:	53
# 		6.5:	9
# 		9.0:	7
# 		2.95:	5
# 		1.5:	3
#   3. created_on_utc
# 	<type 'int'>
# 	Nulls: False
# 	Min: 1451993268
# 	Max: 1451993297
# 	Sum: 145199328274
# 	Mean: 1451993282.74
# 	Median: 1451993282.0
# 	Standard Deviation: 8.94831827775
# 	Unique values: 14
# 	5 most frequent values:
# 		1451993280:	23
# 		1451993290:	21
# 		1451993271:	12
# 		1451993291:	6
# 		1451993297:	6
#   4. discount
# 	<type 'int'>
# 	Nulls: False
# 	Values: 0
#   5. loyalty_visit_id
# 	<type 'int'>
# 	Nulls: False
# ...

# %% [markdown]
# Questions:
#
# Is this an accurate represenation of the data? There are no null values, from our previous conversations it seemed that some of the data may be sparse?
#
# Is there a chance of any of the customer id's being duplicate (i.e. same customer recorded as someone else) will this affect our analysis (this is probably something we will have to answer ourselves)
#
# ...
#
# We will have to:
#
# manipulate date and time variables, currently in one string (easy to manipulate)
#
# merge the data sets by venue_id? that is the only key on all three data sets. or some kind of join to the first two merged on customer id by venue id for the third.
#
# next steps:
#
# get the data into a sql database and explore options of merging sets and what we will work with.

# %% [markdown]
# create sql tables later

# %%
# %load_ext sql

# %%
# %sql mysql://explore:df3@localhost/exploration
